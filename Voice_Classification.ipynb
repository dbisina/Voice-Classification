# %%
# %cd /content/drive/My Drive/Colab Notebooks/SL_ML/LE_3_
# Out:
# /content/drive/My Drive/Colab Notebooks/SL_ML/LE_3_

# %%
#importing libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings #was introduced in Pep230 as a way to warn programmersabout changes in language or libraryb features in anticipation of backwards incompatible changes coming with python 3.0p
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('voice-classification.csv')

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
#data exploration
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
#checking for missing values
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
#getting the shape of data so as to record the total number of labels
print("Shape of Data:", df.shape)
print("Total number of labels: {}".format(df.shape[0]))
print("Number of male: {}".format(df[df.label=='male'].shape[0]))
print("Number of male: {}".format(df[df.label=='female'].shape[0]))
# Out:
# Shape of Data: (3168, 21)
# Total number of labels: 3168
# Number of male: 1584
# Number of male: 1584

# %%
#extract the targety cvariable with an x
X = df.iloc[:, :-1]
print(df.shape)
print(X.shape)
# Out:
# (3168, 21)
# (3168, 20)

# %%
#converting the labels to numerical form
from sklearn.preprocessing import LabelEncoder

# %%
y = df.iloc[:, -1]

gender_encoder = LabelEncoder()
y = gender_encoder.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
#to make the model efficient we have to scale the model between 1 and o
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=100)

# %%
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
SVC_model = SVC()
SVC_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = SVC_model.predict(X_test)

# %%
print('Accuracy Score: ')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9737118822292324

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[458  13]
#  [ 12 468]]

# %%
#Tuning the parameters to get even better
#Optimizi=g the
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C' : [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001]}

# %%
grid = GridSearchCV(SVC(), param_grid,refit=True,verbose=2)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END .....................................C=0.1, gamma=1; total time=   0.7s
# [CV] END .....................................C=0.1, gamma=1; total time=   0.4s
# [CV] END .....................................C=0.1, gamma=1; total time=   0.4s
# [CV] END .....................................C=0.1, gamma=1; total time=   0.4s
# [CV] END .....................................C=0.1, gamma=1; total time=   0.4s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.2s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.2s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.2s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.2s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.2s
# [CV] END ..................................C=0.1, gamma=0.01; total time=   0.2s
# ...

# %%
grid_predictions = grid.predict(X_test)

# %%
print('Accuracy score')
print(metrics.accuracy_score(y_test,grid_predictions))
# Out:
# Accuracy score
# 0.9747634069400631

# %%
print(confusion_matrix(y_test,grid_predictions))
# Out:
# [[459  12]
#  [ 12 468]]

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       471
#            1       0.97      0.97      0.97       480
#
#     accuracy                           0.97       951
#    macro avg       0.97      0.97      0.97       951
# weighted avg       0.97      0.97      0.97       951
